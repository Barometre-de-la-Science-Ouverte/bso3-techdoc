# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import math

# %%
from matplotlib.patches import Rectangle, Circle, Ellipse
colors = plt.cm.Dark2.colors + plt.cm.Accent.colors

fig_width = 20
fig_height = 13

top = fig_height - 0.5

bg_color = 'white'
color="#1e1e1e"
with plt.xkcd():
    fig = plt.figure(figsize=(fig_width, fig_height), dpi=100)
    ax = fig.add_axes((0, 0, 1, 1))
    ax.set_xlim(0, fig_width)
    ax.set_ylim(0, fig_height)
    ax.set_facecolor(bg_color)

    ax.tick_params(bottom=False, top=False,
                   left=False, right=False)
    ax.tick_params(labelbottom=False, labeltop=False,
                   labelleft=False, labelright=False)

    ax.spines["top"].set_color(color)
    ax.spines["bottom"].set_color(color)
    ax.spines["left"].set_color(color)
    ax.spines["right"].set_color(color)
    ax.spines["top"].set_linewidth(4)
    ax.spines["bottom"].set_linewidth(4)
    ax.spines["left"].set_linewidth(4)
    ax.spines["right"].set_linewidth(4)
    
    # colonne 1
    ax.annotate('PDF Harvesting', xy=(2, top), color='#1E1E1E', weight='bold', fontsize=30, ha='center')
    
    ax.add_patch(Ellipse((2.5, top-1), 2, 1.2, edgecolor=colors[0], facecolor='w', linewidth=2))
    ax.annotate('PDF\nharvester', xy=(2.5, top-1.2), color=colors[0], weight='bold', fontsize=20, ha='center')
    ax.annotate("",(18.5,top-2),(3.5,top-0.9),arrowprops=dict(arrowstyle = "<|-", lw=3))
    
    # 2e colonne
    ax.annotate('Mentions detections', xy=(7, top), color='#1E1E1E', weight='bold', fontsize=30, ha='center')
    
    ax.annotate("",(5.7,top-2.2),(3.5,top-1),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((6.5, top-2.5), 2, 1.2, edgecolor=colors[1], facecolor='w', linewidth=2))
    ax.annotate('Softcite', xy=(6.5, top-2.5), color=colors[1], weight='bold', fontsize=20, ha='center')
    
    ax.annotate("",(5.7,top-4.2),(3.5,top-1),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((6.5, top-4.5), 2, 1.2, edgecolor=colors[2], facecolor='w', linewidth=2))
    ax.annotate('DataStet', xy=(6.5, top-4.5), color=colors[2], weight='bold', fontsize=20, ha='center')
    
    ax.annotate("",(5.7,top-6.2),(3.5,top-1),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((6.5, top-6.5), 2, 1.2, edgecolor=colors[3], facecolor='w', linewidth=2))
    ax.annotate('GROBID', xy=(6.5, top-6.5), color=colors[3], weight='bold', fontsize=20, ha='center')
    
    #3e colonne
    ax.annotate('Publication level\nindicators', xy=(13, top-0.5), color='#1E1E1E', weight='bold', fontsize=30, ha='center')
    
    ax.annotate("",(12,top-4.5),(7.5,top-2.6),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(12,top-4.5),(7.5,top-4.6),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(12,top-4.5),(7.5,top-6.6),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Ellipse((13, top-4.5), 2, 1.2, edgecolor=colors[4], facecolor='w', linewidth=2))
    ax.annotate('Analyzer', xy=(13, top-4.5), color=colors[4], weight='bold', fontsize=20, ha='center')
    
    
    #6e colonne
    ax.annotate("",(17.5,top-5.5),(14,top-4.6),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate('Exposition', xy=(18.5, top), color='#1E1E1E', weight='bold', fontsize=30, ha='center')
    
    #ax.annotate("",(17.5,top-7.5+2),(16,top-6),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(18.5,top-10+2),(18.5,top-8+2),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.annotate("",(18.5,top-5+2),(18.5,top-7+2),arrowprops=dict(arrowstyle = "-|>", lw=3))
    ax.add_patch(Rectangle((17.5, top-5+2), 2, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('BSO Open\nData dump', xy=(18.5, top-5+0.2+2), color='#1E1E1E', weight='bold', fontsize=20, ha='center')
    
    ax.add_patch(Rectangle((17.5, top-8+2), 2, 1, edgecolor='#1E1E1E', facecolor='w', linewidth=2))
    ax.annotate('Elasticsearch\n (open API)', xy=(18.5, top-8+0.2+2), color='#1E1E1E', weight='bold', fontsize=20, ha='center')

    ax.add_patch(Ellipse((18.5, top-11+2.3), 2, 1.5, edgecolor=colors[5], facecolor='w', linewidth=2))
    ax.annotate('Web UI\nFrench OSM', xy=(18.5, top-11+0.2+2), color=colors[5], weight='bold', fontsize=20, ha='center')
    
    ax.annotate('Open source code', xy=(12, 2.3), weight='bold', fontsize=20)
    ax.annotate('https://github.com/Barometre-de-la-Science-Ouverte/bso3-harvest-publication', xy=(12, 2.3-0.4), fontsize=15, color=colors[0])
    ax.annotate('https://github.com/ourresearch/software-mentions', xy=(12, 2.3-0.4 - 0.3), fontsize=15, color=colors[1])
    ax.annotate('https://github.com/kermitt2/datastet', xy=(12, 2.3-0.4 - 0.3*2), fontsize=15, color=colors[2])
    ax.annotate('https://github.com/kermitt2/grobid', xy=(12, 2.3-0.4 - 0.3*3), fontsize=15, color=colors[3])
    ax.annotate('https://github.com/Barometre-de-la-Science-Ouverte/bso3-analyze-publication', xy=(12, 2.3-0.4 - 0.3*4), fontsize=15, color=colors[4])
    ax.annotate('https://github.com/dataesr/bso-ui', xy=(12, 2.3-0.4 - 0.3*5), fontsize=15, color=colors[5])
    
    fig.savefig('flow_chart_publications.png')
